# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/Chicago_Crimes_2012_to_2017.csv"
chicago_df = pd.read_csv(csv_file)

chicago_df.head()
# Out:
#    Unnamed: 0        ID Case Number                    Date  \
# 0           3  10508693    HZ250496  05/03/2016 11:40:00 PM
# 1          89  10508695    HZ250409  05/03/2016 09:40:00 PM
# 2         197  10508697    HZ250503  05/03/2016 11:31:00 PM
# 3         673  10508698    HZ250424  05/03/2016 10:10:00 PM
# 4         911  10508699    HZ250455  05/03/2016 10:00:00 PM
#
#                  Block  IUCR            Primary Type              Description  \
# 0   013XX S SAWYER AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 1   061XX S DREXEL AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 2  053XX W CHICAGO AVE  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 3    049XX W FULTON ST  0460                 BATTERY                   SIMPLE
# 4    003XX N LOTUS AVE  0820                   THEFT           $500 AND UNDER
#
#   Location Description  Arrest  ...  Ward  Community Area  FBI Code  \
# ...

# %%
chicago_df = chicago_df.drop(columns=['Unnamed: 0','ID', 'Case Number', 'Location', 'Updated On', 'IUCR'])

# %%
chicago_df
# Out:
#                            Date                 Block            Primary Type  \
# 0        05/03/2016 11:40:00 PM    013XX S SAWYER AVE                 BATTERY
# 1        05/03/2016 09:40:00 PM    061XX S DREXEL AVE                 BATTERY
# 2        05/03/2016 11:31:00 PM   053XX W CHICAGO AVE  PUBLIC PEACE VIOLATION
# 3        05/03/2016 10:10:00 PM     049XX W FULTON ST                 BATTERY
# 4        05/03/2016 10:00:00 PM     003XX N LOTUS AVE                   THEFT
# ...                         ...                   ...                     ...
# 1456709  05/03/2016 11:33:00 PM       026XX W 23RD PL                 BATTERY
# 1456710  05/03/2016 11:30:00 PM   073XX S HARVARD AVE         CRIMINAL DAMAGE
# 1456711  05/03/2016 12:15:00 AM       024XX W 63RD ST                 BATTERY
# 1456712  05/03/2016 09:07:00 PM  082XX S EXCHANGE AVE                 BATTERY
# 1456713  05/03/2016 11:38:00 PM       001XX E 75TH ST           OTHER OFFENSE
#
# ...

# %%
chicago_df.drop(chicago_df.index[chicago_df['Year']>2016], inplace = True)

chicago_df.drop(chicago_df.index[chicago_df['Year']<2013], inplace = True)

# %%
chicago_df.head()
# Out:
#                      Date                Block            Primary Type  \
# 0  05/03/2016 11:40:00 PM   013XX S SAWYER AVE                 BATTERY
# 1  05/03/2016 09:40:00 PM   061XX S DREXEL AVE                 BATTERY
# 2  05/03/2016 11:31:00 PM  053XX W CHICAGO AVE  PUBLIC PEACE VIOLATION
# 3  05/03/2016 10:10:00 PM    049XX W FULTON ST                 BATTERY
# 4  05/03/2016 10:00:00 PM    003XX N LOTUS AVE                   THEFT
#
#                Description Location Description  Arrest  Domestic  Beat  \
# 0  DOMESTIC BATTERY SIMPLE            APARTMENT    True      True  1022
# 1  DOMESTIC BATTERY SIMPLE            RESIDENCE   False      True   313
# 2         RECKLESS CONDUCT               STREET   False     False  1524
# 3                   SIMPLE             SIDEWALK   False     False  1532
# 4           $500 AND UNDER            RESIDENCE   False      True  1523
#
#    District  Ward  Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# ...

# %%
chicago_df.columns
# Out:
# Index(['Date', 'Block', 'Primary Type', 'Description', 'Location Description',
#        'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community Area',
#        'FBI Code', 'X Coordinate', 'Y Coordinate', 'Year', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
chicago_df['Datetime'] = chicago_df['Date'].astype('datetime64')

# %%
chicago_df.dtypes
# Out:
# Date                    datetime64[ns]
# Block                           object
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                       float64
# Ward                           float64
# Community Area                 float64
# FBI Code                        object
# X Coordinate                   float64
# Y Coordinate                   float64
# Year                             int64
# Latitude                       float64
# Longitude                      float64
# dtype: object

# %%
chicago_df
# Out:
#                        Date                 Block            Primary Type  \
# 0       2016-05-03 23:40:00    013XX S SAWYER AVE                 BATTERY
# 1       2016-05-03 21:40:00    061XX S DREXEL AVE                 BATTERY
# 2       2016-05-03 23:31:00   053XX W CHICAGO AVE  PUBLIC PEACE VIOLATION
# 3       2016-05-03 22:10:00     049XX W FULTON ST                 BATTERY
# 4       2016-05-03 22:00:00     003XX N LOTUS AVE                   THEFT
# ...                     ...                   ...                     ...
# 1456709 2016-05-03 23:33:00       026XX W 23RD PL                 BATTERY
# 1456710 2016-05-03 23:30:00   073XX S HARVARD AVE         CRIMINAL DAMAGE
# 1456711 2016-05-03 00:15:00       024XX W 63RD ST                 BATTERY
# 1456712 2016-05-03 21:07:00  082XX S EXCHANGE AVE                 BATTERY
# 1456713 2016-05-03 23:38:00       001XX E 75TH ST           OTHER OFFENSE
#
#                      Description            Location Description  Arrest  \
# ...

# %%
connection_string = "postgres:postgres@localhost:5432/etl_project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['weather', 'chicago_crime']

# %%
chicago_df.to_sql(name='chicago_crime', con=engine, if_exists='append', index=True)
